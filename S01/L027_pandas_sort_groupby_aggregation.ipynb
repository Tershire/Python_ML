# %%
import numpy as np
import pandas as pd

# %%
titanic_df = pd.read_csv("../data/titanic_train.csv")
# titanic_df = pd.read_csv("../data/titanic_train.csv", sep=",")
display(titanic_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
names = ["Eagle", "Eagle", "Hawk", "Sparrow", "Kiwi", "Eagle"]
# scores = np.random.randint(low=0, high=100, size=len(names))
scores = np.array([96, 23, 97, 23, None, 67])
passes = np.zeros_like(scores)
for i, score in enumerate(scores):
    if score is None:
        passes[i] = False
        
    elif score >= 60:
        passes[i] = True        
    else:
        passes[i] = False
    
df = pd.DataFrame(names, columns=["Name"])
df["Score"] = scores
df["Passed"] = passes

df["Note"] = df["Score"] / 100 * 20

display(df)
# Out:
#       Name Score Passed  Note
# 0    Eagle    96   True  19.2
# 1    Eagle    23  False   4.6
# 2     Hawk    97   True  19.4
# 3  Sparrow    23  False   4.6
# 4     Kiwi  None  False   NaN
# 5    Eagle    67   True  13.4

# %% [markdown]
# **.sort_values()**

# %%
# ascending (default)
sorted_df = df.sort_values(by=["Name"])

display(sorted_df)

# descending
sorted_df = df.sort_values(by=["Name"], ascending=False)

display(sorted_df)
# Out:
#       Name Score Passed  Note
# 0    Eagle    96   True  19.2
# 1    Eagle    23  False   4.6
# 5    Eagle    67   True  13.4
# 2     Hawk    97   True  19.4
# 4     Kiwi  None  False   NaN
# 3  Sparrow    23  False   4.6
#       Name Score Passed  Note
# 3  Sparrow    23  False   4.6
# 4     Kiwi  None  False   NaN
# 2     Hawk    97   True  19.4
# 0    Eagle    96   True  19.2
# 1    Eagle    23  False   4.6
# 5    Eagle    67   True  13.4

# %% [markdown]
# *sort with multiple priotized critieria*

# %%
sorted_df = df.sort_values(by=["Name", "Score"])

display(sorted_df)
# Out:
#       Name Score Passed  Note
# 1    Eagle    23  False   4.6
# 5    Eagle    67   True  13.4
# 0    Eagle    96   True  19.2
# 2     Hawk    97   True  19.4
# 4     Kiwi  None  False   NaN
# 3  Sparrow    23  False   4.6

# %% [markdown]
# **aggregation functions**

# %% [markdown]
# *.count()*

# %%
print(df.count())  # None or NaN are not counted
# Out:
# Name      6
# Score     5
# Passed    6
# Note      5
# dtype: int64

# %%
column_names = ["Name", "Score"]

# .count()
print(df[column_names].count())

# .sum()
print(df[column_names].sum())

# .mean()
print(df["Score"].mean())
# Out:
# Name     6
# Score    5
# dtype: int64
# Name     EagleEagleHawkSparrowKiwiEagle
# Score                               306
# dtype: object
# 61.2

# %%
print(df["Score"].agg([sum, max]))
# Out:
# sum    306
# max     97
# Name: Score, dtype: int64

# %% [markdown]
# **.groupby()**

# %%
dfgb = df.groupby(by="Name")

display(dfgb)

# %%
dfgb.mean()
# Out:
#          Score    Passed  Note
# Name
# Eagle     62.0  0.666667  12.4
# Hawk      97.0  1.000000  19.4
# Kiwi       NaN  0.000000   NaN
# Sparrow   23.0  0.000000   4.6

# %%
dfgb[["Score", "Note"]]

dfgb[["Score", "Note"]].mean()
# Out:
#          Score  Note
# Name
# Eagle     62.0  12.4
# Hawk      97.0  19.4
# Kiwi       NaN   NaN
# Sparrow   23.0   4.6

# %% [markdown]
# *Quick Review*

# %%
display(df.groupby(by="Score").count())

display(df.groupby(by="Score")[["Name", "Passed"]].count())
# Out:
#        Name  Passed  Note
# Score
# 23        2       2     2
# 67        1       1     1
# 96        1       1     1
# 97        1       1     1
#        Name  Passed
# Score
# 23        2       2
# 67        1       1
# 96        1       1
# 97        1       1

# %% [markdown]
# **.agg()**

# %%
display(df.groupby(by="Score")[["Name", "Passed"]].agg([sum, max]))

display(df.groupby(by="Name")[["Score", "Passed"]].agg([sum, "mean"]))
# Out:
#                Name          Passed
#                 sum      max    sum    max
# Score
# 23     EagleSparrow  Sparrow      0  False
# 67            Eagle    Eagle   True   True
# 96            Eagle    Eagle   True   True
# 97             Hawk     Hawk   True   True
#         Score       Passed
#           sum  mean    sum      mean
# Name
# Eagle     186  62.0      2  0.666667
# Hawk       97  97.0   True  1.000000
# Kiwi        0   NaN  False  0.000000
# Sparrow    23  23.0  False  0.000000

# %%
agg_format = {"Score": sum, "Passed": "mean"}

display(df.groupby(by=["Name"])[["Score", "Passed"]].agg(agg_format))
# Out:
#         Score    Passed
# Name
# Eagle     186  0.666667
# Hawk       97  1.000000
# Kiwi        0  0.000000
# Sparrow    23  0.000000

# %% [markdown]
# *Ex) Titanic Data*

# %%
agg_format = {"Age": max, "SibSp": sum, "Fare": "mean"}

display(titanic_df.groupby(by=["Pclass"]).agg(agg_format))
# Out:
#          Age  SibSp       Fare
# Pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %%
agg_format = {"Age": [max, "mean"], "Fare": "mean"}

display(titanic_df.groupby(by=["Pclass"]).agg(agg_format))
# Out:
#          Age                  Fare
#          max       mean       mean
# Pclass
# 1       80.0  38.233441  84.154687
# 2       70.0  29.877630  20.662183
# 3       74.0  25.140620  13.675550

# %% [markdown]
# **named aggregation (NamedAgg)**

# %%
titanic_df.groupby(by=["Pclass"]).agg(age_max=("Age", max), age_mean=("Age", np.mean), fare_mean=("Fare", "mean"))
# Out:
#         age_max   age_mean  fare_mean
# Pclass
# 1          80.0  38.233441  84.154687
# 2          70.0  29.877630  20.662183
# 3          74.0  25.140620  13.675550

# %%
titanic_df.groupby(by=["Pclass"]).agg(
    age_max=pd.NamedAgg(column="Age", aggfunc=max),
    age_mean=pd.NamedAgg(column="Age", aggfunc=np.mean),
    fare_mean=pd.NamedAgg(column="Fare", aggfunc="mean")
)
# Out:
#         age_max   age_mean  fare_mean
# Pclass
# 1          80.0  38.233441  84.154687
# 2          70.0  29.877630  20.662183
# 3          74.0  25.140620  13.675550
