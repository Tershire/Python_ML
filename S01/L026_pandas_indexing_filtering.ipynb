# %%
import numpy as np
import pandas as pd

# %%
titanic_df = pd.read_csv("../data/titanic_train.csv")
# titanic_df = pd.read_csv("../data/titanic_train.csv", sep=",")
display(titanic_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
names = ["Eagle", "Penguin", "Hawk", "Sparrow", "Kiwi"]
scores = np.random.randint(low=0, high=100, size=len(names))
passes = scores > 60

df = pd.DataFrame(names, columns=["Name"])
df["Score"] = scores
df["Passed"] = passes

df["Note"] = df["Score"] / 100 * 20

display(df)
# Out:
#       Name  Score  Passed  Note
# 0    Eagle     42   False   8.4
# 1  Penguin     56   False  11.2
# 2     Hawk     88    True  17.6
# 3  Sparrow     67    True  13.4
# 4     Kiwi     77    True  15.4

# %% [markdown]
# *DataFrame[str] -> Series*

# %%
score_sr = df["Score"].head(3)
display(score_sr, type(score_sr), score_sr.shape)
# Out:
# 0    42
# 1    56
# 2    88
# Name: Score, dtype: int32
# pandas.core.series.Series
# (3,)

# %% [markdown]
# *DataFrame[list] -> DataFrame*

# %%
# single column
score_df = df[["Score"]].head(3)
display(score_df, type(score_df), score_df.shape)

# multiple columns
sub_df = df[["Score", "Note"]].head(3)
display(sub_df, type(sub_df), sub_df.shape)
# Out:
#    Score
# 0     42
# 1     56
# 2     88
# pandas.core.frame.DataFrame
# (3, 1)
#    Score  Note
# 0     42   8.4
# 1     56  11.2
# 2     88  17.6
# pandas.core.frame.DataFrame
# (3, 2)

# %%
df.index = ["I", "II", "III", "IV", "V"]

display(df)
# Out:
#         Name  Score  Passed  Note
# I      Eagle     42   False   8.4
# II   Penguin     56   False  11.2
# III     Hawk     88    True  17.6
# IV   Sparrow     67    True  13.4
# V       Kiwi     77    True  15.4

# %% [markdown]
# **iloc[]**

# %%
print(df.iloc[1, 0])
# Out:
# Penguin

# %%
# all
display(df.iloc[:])

# 
display(df.iloc[1:4])

# 
display(df.iloc[[0, 2, 3], :-1])
# Out:
#         Name  Score  Passed  Note
# I      Eagle     42   False   8.4
# II   Penguin     56   False  11.2
# III     Hawk     88    True  17.6
# IV   Sparrow     67    True  13.4
# V       Kiwi     77    True  15.4
#         Name  Score  Passed  Note
# II   Penguin     56   False  11.2
# III     Hawk     88    True  17.6
# IV   Sparrow     67    True  13.4
#         Name  Score  Passed
# I      Eagle     42   False
# III     Hawk     88    True
# IV   Sparrow     67    True

# %% [markdown]
# *<!> iloc[] does not support Boolean Indexing <!>*

# %% [markdown]
# **loc[]**

# %%
print(df.loc["II", "Name"])
# Out:
# Penguin

# %%
# 
display(df.loc["II":"IV"])

# 
display(df.loc[["I", "III", "IV"], ["Name", "Score", "Passed"]])
# Out:
#         Name  Score  Passed  Note
# II   Penguin     56   False  11.2
# III     Hawk     88    True  17.6
# IV   Sparrow     67    True  13.4
#         Name  Score  Passed
# I      Eagle     42   False
# III     Hawk     88    True
# IV   Sparrow     67    True

# %% [markdown]
# *<O> loc[] supports Boolean Indexing <O>*

# %%
display(df.loc[df.Passed])

display(df.loc[df.Score % 2 == 1])
# Out:
#         Name  Score  Passed  Note
# III     Hawk     88    True  17.6
# IV   Sparrow     67    True  13.4
# V       Kiwi     77    True  15.4
#        Name  Score  Passed  Note
# IV  Sparrow     67    True  13.4
# V      Kiwi     77    True  15.4

# %% [markdown]
# **Example**

# %%
display(titanic_df[titanic_df.Age > 65])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
display(titanic_df[titanic_df.Age > 65][["Name", "Age", "Pclass", "Survived"]])
# Out:
#                                      Name   Age  Pclass  Survived
# 33                  Wheadon, Mr. Edward H  66.0       2         0
# 96              Goldschmidt, Mr. George B  71.0       1         0
# 116                  Connors, Mr. Patrick  70.5       3         0
# 493               Artagaveytia, Mr. Ramon  71.0       1         0
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0       1         1
# 672           Mitchell, Mr. Henry Michael  70.0       2         0
# 745          Crosby, Capt. Edward Gifford  70.0       1         0
# 851                   Svensson, Mr. Johan  74.0       3         0

# %%
display(titanic_df[(titanic_df.Age > 65) & (titanic_df.Pclass == 1)][["Name", "Age", "Pclass", "Survived"]])
# Out:
#                                      Name   Age  Pclass  Survived
# 96              Goldschmidt, Mr. George B  71.0       1         0
# 493               Artagaveytia, Mr. Ramon  71.0       1         0
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0       1         1
# 745          Crosby, Capt. Edward Gifford  70.0       1         0
