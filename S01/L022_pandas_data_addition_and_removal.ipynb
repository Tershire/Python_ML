# %%
import numpy as np
import pandas as pd

# %%
titanic_df = pd.read_csv("./data/titanic_train.csv")
# titanic_df = pd.read_csv("./data/titanic_train.csv", sep=",")
display(titanic_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dict = {"Score": [57, 92, 83], "Passed": [False, True, True]}
df = pd.DataFrame(dict)

display(df_from_dict)
# Out:
#    Score  Passed
# 0     57   False
# 1     92    True
# 2     83    True

# %% [markdown]
# **add, initialize, and update a new column**

# %%
df["Note"] = 0  # initialize with 0

display(df)
# Out:
#    Score  Passed  Note
# 0     57   False     0
# 1     92    True     0
# 2     83    True     0

# %%
df["Note"] = df["Score"] / 100 * 20

display(df)
# Out:
#    Score  Passed  Note
# 0     57   False  11.4
# 1     92    True  18.4
# 2     83    True  16.6

# %% [markdown]
# *ex) update*

# %%
df["Note"] = df["Note"] + 1.5

display(df)
# Out:
#    Score  Passed  Note
# 0     57   False  12.9
# 1     92    True  19.9
# 2     83    True  18.1

# %% [markdown]
# **remove a column**

# %%
df_new = df.drop("Note", axis=1)  # inplace=False by default

display(df_new, df)
# Out:
#    Score  Passed
# 0     57   False
# 1     92    True
# 2     83    True
#    Score  Passed  Note
# 0     57   False  12.9
# 1     92    True  19.9
# 2     83    True  18.1

# %% [markdown]
# **remove multiple columns**

# %%
column_names = ["#1", "#2", "#3"]
df[column_names] = 0

display(df)
# Out:
#    Score  Passed  Note  #1  #2  #3
# 0     57   False  12.9   0   0   0
# 1     92    True  19.9   0   0   0
# 2     83    True  18.1   0   0   0

# %%
items_to_remove = ["#1", "#3"]
df.drop(items_to_remove, axis=1, inplace=True)

display(df)
# Out:
#    Score  Passed  Note  #2
# 0     57   False  12.9   0
# 1     92    True  19.9   0
# 2     83    True  18.1   0

# %%
df.loc[len(df)] = [36, False, 0, 0]

display(df)
# Out:
#    Score  Passed  Note  #2
# 0     57   False  12.9   0
# 1     92    True  19.9   0
# 2     83    True  18.1   0
# 3     36   False   0.0   0

# %%
df.drop([0, 3], axis=0, inplace=True)

display(df)
# Out:
#    Score  Passed  Note  #2
# 1     92    True  19.9   0
# 2     83    True  18.1   0
